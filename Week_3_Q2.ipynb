# %% [markdown]
# ## Extracting Lat and Long of Ontario Canada - Part 2

# %%
# import more libraries
import numpy as np
import random
import pandas as pd


# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim

from IPython.display import Image
from IPython.core.display import HTML

! conda install -c conda-forge folium=0.5.0 --yes
import folium 

print('done')
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# done

# %%
geo_data="Geospatial_Coordinates.csv"

df_1=pd.read_csv(geo_data)

df_1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# ensure that both dataframes- df from part one and this df have the same shape

df_1.shape
# Out:
# (103, 3)

# %%
# change column names inorder to merger both dataframes

df_1.columns=['Postcode','Latitude','Longitude']

cols=df_1.columns.tolist()
cols
# Out:
# ['Postcode', 'Latitude', 'Longitude']

# %%
# Read the first datafram created in part 1 of the assignment

table="week_3_Q1.csv"

df=pd.read_csv(table)

df.head()
# Out:
#    Unnamed: 0 Postcode      Borough                           Neighbourhood
# 0           0      M1B  Scarborough                          Rouge ,Malvern
# 1           1      M1C  Scarborough  Highland Creek ,Rouge Hill ,Port Union
# 2           2      M1E  Scarborough       Guildwood ,Morningside ,West Hill
# 3           3      M1G  Scarborough                                  Woburn
# 4           4      M1H  Scarborough                               Cedarbrae

# %%
df_3=pd.merge(df, df_1, on="Postcode")
df_3.head()
# Out:
#    Unnamed: 0 Postcode      Borough                           Neighbourhood  \
# 0           0      M1B  Scarborough                          Rouge ,Malvern
# 1           1      M1C  Scarborough  Highland Creek ,Rouge Hill ,Port Union
# 2           2      M1E  Scarborough       Guildwood ,Morningside ,West Hill
# 3           3      M1G  Scarborough                                  Woburn
# 4           4      M1H  Scarborough                               Cedarbrae
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %%
# delete unwanted column

del df_3["Unnamed: 0"]

df_3.head(12)
# Out:
#    Postcode      Borough                                      Neighbourhood  \
# 0       M1B  Scarborough                                     Rouge ,Malvern
# 1       M1C  Scarborough             Highland Creek ,Rouge Hill ,Port Union
# 2       M1E  Scarborough                  Guildwood ,Morningside ,West Hill
# 3       M1G  Scarborough                                             Woburn
# 4       M1H  Scarborough                                          Cedarbrae
# 5       M1J  Scarborough                                Scarborough Village
# 6       M1K  Scarborough        East Birchmount Park ,Ionview ,Kennedy Park
# 7       M1L  Scarborough                    Clairlea ,Golden Mile ,Oakridge
# 8       M1M  Scarborough    Cliffcrest ,Cliffside ,Scarborough Village West
# 9       M1N  Scarborough                        Birch Cliff ,Cliffside West
# 10      M1P  Scarborough  Dorset Park ,Scarborough Town Centre ,Wexford ...
# ...

# %% [markdown]
# ## Save to a csv for the last part of this assignment

# %%
df_3.to_csv(r'week_3_part_2.csv')
